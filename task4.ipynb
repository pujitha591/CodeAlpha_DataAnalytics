# %% [markdown]
# <a href="https://colab.research.google.com/github/pujitha591/CodeAlpha_DataAnalytics/blob/main/task4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt
import seaborn as sns

# Load Dataset
df = pd.read_excel("/reviews dataset.xlsx")

# Function for Sentiment Analysis
def get_sentiment(text):
    polarity = TextBlob(str(text)).sentiment.polarity

    if polarity > 0:
        return "Positive"
    elif polarity < 0:
        return "Negative"
    else:
        return "Neutral"

# Apply Sentiment Analysis
df["Sentiment"] = df["Review"].apply(get_sentiment)

# Display Dataset
print(df)

# Count sentiments
print(df["Sentiment"].value_counts())

# Save Output
df.to_csv("Sentiment_Output.csv", index=False)

# Visualization
sns.set(style="whitegrid")

plt.figure(figsize=(6,5))
sns.countplot(x="Sentiment", data=df)

plt.title("Sentiment Analysis")
plt.xlabel("Sentiment")
plt.ylabel("Number of Reviews")

plt.show()
# Out:
#                           Review Sentiment
# 0       This product is amazing.  Positive
# 1      I love this mobile phone.  Positive
# 2              Very bad quality.  Negative
# 3           Worst purchase ever.  Negative
# 4         Excellent performance.  Positive
# 5               Average product.  Negative
# 6                    It is okay.  Positive
# 7          Fantastic experience.  Positive
# 8           Not worth the money.  Negative
# 9            Highly recommended.  Positive
# 10    Terrible customer service.  Negative
# 11       Battery backup is good.  Positive
# 12  Screen quality is excellent.  Positive
# 13          I hate this product.  Negative
# 14         Good value for money.  Positive
# Sentiment
# Positive    9
# Negative    6
# Name: count, dtype: int64
