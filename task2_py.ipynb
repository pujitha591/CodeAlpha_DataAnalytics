# %%
# ============================================
# TASK 2: Exploratory Data Analysis (EDA)
# Example Dataset: Titanic
# ============================================

# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# Load Dataset
# Download Titanic dataset from Kaggle and place 'Titanic-Dataset.csv'
# in the same folder as this Python file.

df = pd.read_excel("/Titanic-Dataset.xlsx")

# --------------------------------------------
# 1. Meaningful Questions Before Analysis
# --------------------------------------------
print("Meaningful Questions:")
print("1. How many passengers are in the dataset?")
print("2. What are the different variables?")
print("3. What are the data types?")
print("4. Are there any missing values?")
print("5. Are there duplicate records?")
print("6. What is the survival rate?")
print("7. What is the age distribution?")
print("8. Is there a relationship between age and fare?")
print("9. Which passenger class had the highest survival?")
print("10. Is gender related to survival?")

# --------------------------------------------
# 2. Explore Dataset Structure
# --------------------------------------------

print("\nDataset Shape:")
print(df.shape)

print("\nColumn Names:")
print(df.columns)

print("\nData Types:")
print(df.dtypes)

print("\nDataset Information:")
print(df.info())

print("\nFirst 5 Rows:")
print(df.head())

# --------------------------------------------
# 3. Summary Statistics
# --------------------------------------------

print("\nSummary Statistics:")
print(df.describe())

# --------------------------------------------
# 4. Missing Values
# --------------------------------------------

print("\nMissing Values:")
print(df.isnull().sum())

# --------------------------------------------
# 5. Duplicate Records
# --------------------------------------------

print("\nDuplicate Records:")
print(df.duplicated().sum())

# --------------------------------------------
# 6. Unique Values
# --------------------------------------------

print("\nUnique Values:")
print(df.nunique())

# --------------------------------------------
# 7. Correlation Matrix
# --------------------------------------------

print("\nCorrelation Matrix:")
print(df.corr(numeric_only=True))

# --------------------------------------------
# 8. Survival Count
# --------------------------------------------

print("\nSurvival Count:")
print(df['Survived'].value_counts())

# --------------------------------------------
# 9. Passenger Class Count
# --------------------------------------------

print("\nPassenger Class Count:")
print(df['Pclass'].value_counts())

# --------------------------------------------
# 10. Gender Count
# --------------------------------------------

print("\nGender Count:")
print(df['Sex'].value_counts())

# ============================================
# Data Visualization
# ============================================

# Age Distribution
plt.figure(figsize=(6,4))
plt.hist(df['Age'].dropna(), bins=20)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# Survival Count
plt.figure(figsize=(5,4))
df['Survived'].value_counts().plot(kind='bar')
plt.title("Survival Count")
plt.xlabel("Survived (0 = No, 1 = Yes)")
plt.ylabel("Passengers")
plt.show()

# Passenger Class
plt.figure(figsize=(5,4))
df['Pclass'].value_counts().plot(kind='bar')
plt.title("Passenger Class")
plt.xlabel("Class")
plt.ylabel("Passengers")
plt.show()

# Gender Distribution
plt.figure(figsize=(5,4))
df['Sex'].value_counts().plot(kind='bar')
plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Passengers")
plt.show()

# Fare Distribution
plt.figure(figsize=(6,4))
plt.hist(df['Fare'], bins=20)
plt.title("Fare Distribution")
plt.xlabel("Fare")
plt.ylabel("Frequency")
plt.show()

# Scatter Plot
plt.figure(figsize=(6,4))
plt.scatter(df['Age'], df['Fare'])
plt.title("Age vs Fare")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.show()

print("\nEDA Completed Successfully!")
# Out:
# Meaningful Questions:
# 1. How many passengers are in the dataset?
# 2. What are the different variables?
# 3. What are the data types?
# 4. Are there any missing values?
# 5. Are there duplicate records?
# 6. What is the survival rate?
# 7. What is the age distribution?
# 8. Is there a relationship between age and fare?
# 9. Which passenger class had the highest survival?
# 10. Is gender related to survival?
#
# Dataset Shape:
# (10, 12)
#
# Column Names:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
#
# Data Types:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
#
# Dataset Information:
# ...
